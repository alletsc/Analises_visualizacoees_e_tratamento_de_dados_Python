# %%
import pandas as pd
import seaborn as sns

# %%
base_rs = pd.read_csv(
    "S:\gits_stella\Analises_visualizacoees_e_tratamento_de_dados_Python\dados\dados.csv", sep = ';')
base_rs.head()
# Out:
#    CODIGO               MUNICIPIO       PIB  VALOREMPENHO
# 0     106   SANTANA DO LIVRAMENTO  12240.76    1088666.10
# 1     113            SANTO ANGELO  16575.82     800669.92
# 2     118  SAO FRANCISCO DE ASSIS  12037.61     466122.80
# 3      13         CACAPAVA DO SUL  13674.54     485535.86
# 4     120             SAO GABRIEL  19912.38     533719.86

# %%
base_rs.shape
# Out:
# (187, 4)

# %%
sns.histplot(base_rs.PIB, bins = 10, kde = True, stat='density',
             linewidth = 1, color = "green").set_title("PIB")
# Out:
# Text(0.5, 1.0, 'PIB')

# %%
mean_PIB = base_rs['PIB'].mean()
mean_PIB
# Out:
# 19808.741336898394

# %%
sns.jointplot(x = 'VALOREMPENHO', y = 'PIB', data = base_rs, color = 'purple', kind = 'reg')

# %%
sns.histplot(base_rs.VALOREMPENHO, bins=10, kde=True, stat='density',
             linewidth=1, color="gray").set_title('Empenho')
# Out:
# Text(0.5, 1.0, 'Empenho')

# %%
agrupado = base_rs.sort_values('PIB').head(10)
agrupado = agrupado.iloc[:, 1:3]
agrupado
agrupado.plot.bar(x='MUNICIPIO', y='PIB', color= 'red')
# Out:
# <AxesSubplot:xlabel='MUNICIPIO'>

# %%
agrupado = base_rs.sort_values('VALOREMPENHO').head(10)
agrupado = agrupado.iloc[:, [1, 3]]
agrupado
agrupado.plot.bar(x='MUNICIPIO', y='VALOREMPENHO', color='gray')
# Out:
# <AxesSubplot:xlabel='MUNICIPIO'>
