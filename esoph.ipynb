# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
base_esoph = pd.read_csv(
    "S:\gits_stella\Analises_visualizacoees_e_tratamento_de_dados_Python\dados\esoph.csv")

# %%
base_esoph.head()
# Out:
#    agegp      alcgp     tobgp  ncases  ncontrols
# 0  25-34  0-39g/day  0-9g/day       0         40
# 1  25-34  0-39g/day     10-19       0         10
# 2  25-34  0-39g/day     20-29       0          6
# 3  25-34  0-39g/day       30+       0          5
# 4  25-34      40-79  0-9g/day       0         27

# %%
sns.catplot(x='alcgp', y='ncontrols', data=base_esoph, jitter=False,)

# %%
sns.catplot(x='alcgp', y='ncontrols', data=base_esoph, col='tobgp')
